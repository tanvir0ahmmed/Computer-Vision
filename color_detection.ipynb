# %% [markdown]
# <a href="https://colab.research.google.com/github/tanvir0ahmmed/Computer-Vision/blob/Practice/color_detection.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pyplot as plt
import cv2

# %%
image = cv2.imread('/content/drive/My Drive/UpWork/Computer Vision/Practice/Color Detection/Data File/254554.jpg')
print(type(image))
print(image.shape)
# Out:
# <class 'numpy.ndarray'>
# (2668, 4000, 3)

# %%
# %matplotlib inline

img = np.copy(image)
img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
plt.imshow(image)

# %%
 plt.imshow(img)

# %%
lower_range = np.array([0, 176, 0])
upper_range = np.array([120, 186, 62])

mask = cv2.inRange(img, lower_range, upper_range)
plt.imshow(mask, cmap='gray')

# %%
mask_img = np.copy(img)
mask_img[mask != 0] = [0,0,0]
plt.imshow(mask_img)
